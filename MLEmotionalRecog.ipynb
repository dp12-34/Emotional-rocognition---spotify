# %%
from deepface import DeepFace as dp
import cv2
import matplotlib.pyplot as ppt
import uuid
import os

# %%
REAL_PATH = os.path.join('data', 'tests')

# %%
capture = cv2.VideoCapture(0)
while capture.isOpened():
    ret, frame = capture.read()

    frame = frame[100:100+250,200:200+250,:]

    if cv2.waitKey(1) & 0XFF == ord('c'):
        imgname = os.path.join(REAL_PATH, '{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname,frame)
        break;

    cv2.imshow('Image Collection', frame)
    # if cv2.waitKey(1) & 0XFF == ord('q'):
    #     break
capture.release()
cv2.destroyAllWindows()

# %%
i_path = imgname

# %%
img = cv2.imread(i_path)

# %%
ppt.imshow(img[:,:,::-1])

# %%
demo = dp.analyze(i_path, enforce_detection=False)
demo
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.91it/s]
# [{'emotion': {'angry': 0.09735337222109702,
#    'disgust': 0.010325281394539419,
#    'fear': 13.193138026373152,
#    'happy': 46.131214038278344,
#    'sad': 22.033512238682775,
#    'surprise': 3.18915605749595e-05,
#    'neutral': 18.534427110484494},
#   'dominant_emotion': 'happy',
#   'region': {'x': 0, 'y': 0, 'w': 250, 'h': 250},
#   'age': 26,
#   'gender': {'Woman': 0.00543976784683764, 'Man': 99.99456405639648},
#   'dominant_gender': 'Man',
#   'race': {'asian': 5.30351921328327e-07,
#    'indian': 1.7642701550390323e-05,
#    'black': 5.8195208375951914e-08,
#    'white': 99.72345236260267,
#    'middle eastern': 0.1971700692197598,
#    'latino hispanic': 0.0793581035380836},
#   'dominant_race': 'white'}]

# %%
main_emotion = demo[0]['dominant_emotion']  
if main_emotion == 'discust':
    print("No time for music! Your main emotion is " + main_emotion +  " Go exercise.")
else:
    print("Your main emotion was " + main_emotion)
# Out:
# Your main emotion was happy
